# %%
import pandas as pd
data = pd.read_csv("data.csv")

# %%
# convert the data from dataframe to dictionary as mongo db is key value databases
data_dict = data.to_dict(orient="records")

# %%
DB_name = "MLOps-day10" # user defined name
Collection_name = "MLOps-day10-cl" # user defined name
connection_stg = "replace with connection string"

# %%
from pymongo import MongoClient

# Replace with your actual connection string
client = MongoClient(connection_stg)
db = client[DB_name]
collection = db[Collection_name]
# Project --> database --> collection , is the hierarchy in mongo db

# %%
collection.insert_many(data_dict)

# %%
import traceback

try:
    1 / 0
except Exception as e:
    tb = traceback.format_exc()
    print(type(tb))

# %%
import traceback
import sys

try:
    x = undefined_var
except:
    exc_type, exc_value, exc_tb = sys.exc_info()
    details = traceback.extract_tb(exc_tb)
    print(details)

# %%
exc_type, exc_value, exc_tb

# %%
import traceback

try:
    int("abc")
except Exception:
    frames = traceback.format_tb(sys.exc_info()[2])
    print(frames)

# %%
from src.configuration.mongo_db_connection import MongoDBClient
MongoDBClient()

# %%
from src.entity.artifact_entity import DataIngestionArtifact
DataIngestionArtifact.trained_file_path
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 from src.entity.artifact_entity import DataIngestionArtifact
# ----> 2 DataIngestionArtifact.trained_file_path
#
# AttributeError: type object 'DataIngestionArtifact' has no attribute 'trained_file_path'
